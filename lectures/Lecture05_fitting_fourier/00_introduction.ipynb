# %% [markdown]
# # AY128 Lecture 5: Dust, Fourier, and Fitting
# Feb 5, 2026
#
# ## Agenda
#
# - Introduction (this notebook, *00_Introduction*)
# - Dust (*01_exinction*)
# - More on periodograms (aliasing, harmonics, and resampling) (*02_periodograms*)
# - Fitting tools (*03_fitting_tutorial*)
