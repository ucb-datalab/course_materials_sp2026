# %%
# %run ../talktools.py

# %% [markdown]
# <img src="http://s2.quickmeme.com/img/22/228c7e9afc0352e0b7a890e3f358afebfe2882c37efacae7ab8bc551468afbf4.jpg">

# %% [markdown]
# # Debugging Code #
#
#  * Standard technique of inserting “print” statements may be inconvenient if code takes a long time to run
#  * The module `pdb` is an interactive source  debugger
#  * Variables are preserved at breakpoint, and can interactively step through lines of code
#
#  http://docs.python.org/library/pdb.html
#
# Use `pdb.set_trace()` to explore and interact with problematic code:
# ```python
# #[ in some problematic python file ]
# import pdb
# #[ code code code ]
# pdb.set_trace()   # hard-code a breakpoint at a given point in a program
# #[ problematic code ]
# ```
# using from the command line:
# ```bash
# python -m pdb myscript.py
# ```
# pdb will automatically enter post-mortem debugging if the program being debugged exits abnormally.

# %% [markdown]
#  Can debug within iPython by typing `%debug` after exception is raised
# ‘help’ shows the commands available, for both pdb and iPython’s ipdb

# %%
def horrible_function(x):
    print(1/x)

# %%
horrible_function(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/l6/qxz619j9671dr9wn886bbk540000gn/T/ipykernel_14834/2918912784.py in <module>
# ----> 1 horrible_function(0)
#
# /var/folders/l6/qxz619j9671dr9wn886bbk540000gn/T/ipykernel_14834/630055883.py in horrible_function(x)
#       1 def horrible_function(x):
# ----> 2     print(1/x)
#
# ZeroDivisionError: division by zero

# %%
# %debug
# Out:
# > /var/folders/l6/qxz619j9671dr9wn886bbk540000gn/T/ipykernel_14834/630055883.py(2)horrible_function()
#       1 def horrible_function(x):
# ----> 2     print(1/x)
# ipdb>  q

# %%
# this currently fails https://github.com/matplotlib/matplotlib/issues/22207
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d
import matplotlib.testing.jpl_units as units
units.register()

x = [i * units.km for i in range(10)]
y = [2 * i * units.km for i in range(10)]
z = [3 * i * units.km for i in range(10)]

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot(x, y, z)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/l6/qxz619j9671dr9wn886bbk540000gn/T/ipykernel_14834/2725238231.py in <module>
#      11 fig = plt.figure()
#      12 ax = fig.add_subplot(projection="3d")
# ---> 13 ax.plot(x, y, z)
#      14 plt.show()
#
# ~/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot(self, xs, ys, zdir, *args, **kwargs)
#    1500
#    1501         xs, ys, zs = art3d.juggle_axes(xs, ys, zs, zdir)
# -> 1502         self.auto_scale_xyz(xs, ys, zs, had_data)
#    1503         return lines
#    1504
#
# ~/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py in auto_scale_xyz(self, X, Y, Z, had_data)
#     650         # minimum sized rectangular volume holds the data.
#     651         if np.shape(X) == np.shape(Y):
# --> 652             self.xy_dataLim.update_from_data_xy(
#     653                 np.column_stack([np.ravel(X), np.ravel(Y)]), not had_data)
#     654         else:
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/transforms.py in update_from_data_xy(self, xy, ignore, updatex, updatey)
#     965             return
#     966
# --> 967         path = Path(xy)
#     968         self.update_from_path(path, ignore=ignore,
#     969                               updatex=updatex, updatey=updatey)
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     127             and codes as read-only arrays.
#     128         """
# --> 129         vertices = _to_unmasked_float_array(vertices)
#     130         _api.check_shape((None, 2), vertices=vertices)
#     131
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1296         return np.ma.asarray(x, float).filled(np.nan)
#    1297     else:
# -> 1298         return np.asarray(x, float)
#    1299
#    1300
#
# ~/ay250/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# TypeError: float() argument must be a string or a number, not 'UnitDbl'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/ay250/lib/python3.9/site-packages/matplotlib/testing/jpl_units/UnitDbl.py in _binop_unit_unit(self, op, rhs)
#     105         """Check that *self* and *rhs* share units; combine them using *op*."""
# --> 106         self.checkSameUnits(rhs, op.__name__)
#     107         return UnitDbl(op(self._value, rhs._value), self._units)
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/testing/jpl_units/UnitDbl.py in checkSameUnits(self, rhs, func)
#     176         """
# --> 177         if self._units != rhs._units:
#     178             raise ValueError(f"Cannot {func} units of different types.\n"
#
# AttributeError: 'float' object has no attribute '_units'
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/ay250/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/ay250/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2808
#    2809             self.patch.draw(renderer)
# -> 2810             mimage._draw_list_compositing_images(
#    2811                 renderer, self, artists, self.suppressComposite)
#    2812
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     471
#     472             # Then rest
# --> 473             super().draw(renderer)
#     474
#     475     def get_axis_position(self):
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3080             renderer.stop_rasterizing()
#    3081
# -> 3082         mimage._draw_list_compositing_images(
#    3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/ay250/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/art3d.py in draw(self, renderer)
#     214     def draw(self, renderer):
#     215         xs3d, ys3d, zs3d = self._verts3d
# --> 216         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, self.axes.M)
#     217         self.set_data(xs, ys)
#     218         super().draw(renderer)
#
# ~/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform(xs, ys, zs, M)
#     142     """
#     143     vec = _vec_pad_ones(xs, ys, zs)
# --> 144     return _proj_transform_vec(vec, M)
#     145
#     146
#
# ~/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/proj3d.py in _proj_transform_vec(vec, M)
#     104
#     105 def _proj_transform_vec(vec, M):
# --> 106     vecw = np.dot(M, vec)
#     107     w = vecw[3]
#     108     # clip here..
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ~/ay250/lib/python3.9/functools.py in __get__(self, obj, cls)
#     391
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#     395         if get is not None:
#
# SystemError: <built-in function getattr> returned a result with an error set

# %%
# %debug
# Out:
# > /Users/jbloom/ay250/lib/python3.9/functools.py(393)__get__()
#     391
#     392     def __get__(self, obj, cls=None):
# --> 393         get = getattr(self.func, "__get__", None)
#     394         result = None
#     395         if get is not None:
# ipdb>  u
# > <__array_function__ internals>(5)dot()
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/proj3d.py(106)_proj_transform_vec()
#     104
#     105 def _proj_transform_vec(vec, M):
# --> 106     vecw = np.dot(M, vec)
#     107     w = vecw[3]
#     108     # clip here..
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/proj3d.py(144)proj_transform()
#     142     """
#     143     vec = _vec_pad_ones(xs, ys, zs)
# --> 144     return _proj_transform_vec(vec, M)
#     145
#     146
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/art3d.py(216)draw()
#     214     def draw(self, renderer):
#     215         xs3d, ys3d, zs3d = self._verts3d
# --> 216         xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, self.axes.M)
#     217         self.set_data(xs, ys)
#     218         super().draw(renderer)
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/artist.py(50)draw_wrapper()
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/image.py(132)_draw_list_compositing_images()
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/axes/_base.py(3082)draw()
#    3080             renderer.stop_rasterizing()
#    3081
# -> 3082         mimage._draw_list_compositing_images(
#    3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
# ipdb>
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/artist.py(50)draw_wrapper()
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py(473)draw()
#     471
#     472             # Then rest
# --> 473             super().draw(renderer)
#     474
#     475     def get_axis_position(self):
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/artist.py(50)draw_wrapper()
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/image.py(132)_draw_list_compositing_images()
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/figure.py(2810)draw()
#    2808
#    2809             self.patch.draw(renderer)
# -> 2810             mimage._draw_list_compositing_images(
#    2811                 renderer, self, artists, self.suppressComposite)
#    2812
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/artist.py(50)draw_wrapper()
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/artist.py(73)draw_wrapper()
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/matplotlib/backend_bases.py(2295)print_figure()
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/IPython/core/pylabtools.py(151)print_figure()
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
# ipdb>  u
# > /Users/jbloom/ay250/lib/python3.9/site-packages/IPython/core/formatters.py(341)__call__()
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
# ipdb>
# *** Oldest frame
# ipdb>  u
# *** Oldest frame
# ipdb>  u
# *** Oldest frame
# ipdb>  q

# %% [markdown]
# # Good coding style
#
#  - There is an official Python style guide, called PEP8:
#     http://www.python.org/dev/peps/pep-0008/
#
#  - Guido sez: 'code is read much more often than it is written'
#      - especially true for scientific code
#
#  - Python enables you to write readable code, so do it!  The world will seem a happier place.
#
#  - **`ruff`** is the modern, fast (Rust-based) linter and formatter that replaces `flake8`, `black`, `isort`, and many other tools in one: https://docs.astral.sh/ruff/
#
#  - Older tools you may encounter: `pylint`, `pycodestyle`, `flake8`, `black`
#
#  - Run ruff like: `ruff check my_code.py` (linting) and `ruff format my_code.py` (formatting)
#
#  - and please dont forget docstrings: https://sphinxcontrib-napoleon.readthedocs.io/en/latest/example_numpy.html#example-numpy
#
# cf. https://github.com/vintasoftware/python-linters-and-code-analysis

# %%
# %%writefile less_ugly.py
"""love those DOCSTRINGs
"""

def ugly_stuff(title="my title"):
    #not a great snippet of code here
    if not results.fill:
                histOutline.OutlinedHistogram(data,title   = title)
    else:
            histOutline.RegularHistogram(data,title  =   title)
# Out:
# Overwriting less_ugly.py

# %%
# !uv pip install ruff
# Out:
# Using Python 3.12.9 environment at: /Users/jbloom/Classes/ay256/course_materials_sp2026/.venv
# Resolved 1 package in 77ms
# Installed 1 package in 143ms
#  + ruff==0.15.1

# %%
# !ruff check less_ugly.py
# Out:
# F821 Undefined name `results`
#  --> less_ugly.py:6:12
#   |
# 4 | def ugly_stuff(title="my title"):
# 5 |     #not a great snippet of code here
# 6 |     if not results.fill:
#   |            ^^^^^^^
# 7 |                 histOutline.OutlinedHistogram(data,title   = title)
# 8 |     else:
#   |
#
# F821 Undefined name `histOutline`
#  --> less_ugly.py:7:17
#   |
# 5 |     #not a great snippet of code here
# 6 |     if not results.fill:
# 7 |                 histOutline.OutlinedHistogram(data,title   = title)
#   |                 ^^^^^^^^^^^
# 8 |     else:
# 9 |             histOutline.RegularHistogram(data,title  =   title)
#   |
#
# F821 Undefined name `data`
#  --> less_ugly.py:7:47
#   |
# 5 |     #not a great snippet of code here
# 6 |     if not results.fill:
# 7 |                 histOutline.OutlinedHistogram(data,title   = title)
#   |                                               ^^^^
# 8 |     else:
# 9 |             histOutline.RegularHistogram(data,title  =   title)
#   |
#
# F821 Undefined name `histOutline`
#  --> less_ugly.py:9:13
#   |
# 7 |                 histOutline.OutlinedHistogram(data,title   = title)
# 8 |     else:
# 9 |             histOutline.RegularHistogram(data,title  =   title)
#   |             ^^^^^^^^^^^
#   |
#
# F821 Undefined name `data`
#  --> less_ugly.py:9:42
#   |
# 7 |                 histOutline.OutlinedHistogram(data,title   = title)
# 8 |     else:
# 9 |             histOutline.RegularHistogram(data,title  =   title)
#   |                                          ^^^^
#   |
#
# Found 5 errors.

# %% [markdown]
# We can fix it with `ruff format`:

# %%
# !ruff format less_ugly.py
# Out:
# 1 file reformatted

# %%
# !cat less_ugly.py
# Out:
# """love those DOCSTRINGs"""
#
#
# def ugly_stuff(title="my title"):
#     # not a great snippet of code here
#     if not results.fill:
#         histOutline.OutlinedHistogram(data, title=title)
#     else:
#         histOutline.RegularHistogram(data, title=title)

# %%
# !ruff check less_ugly.py
# Out:
# F821 Undefined name `results`
#  --> less_ugly.py:6:12
#   |
# 4 | def ugly_stuff(title="my title"):
# 5 |     # not a great snippet of code here
# 6 |     if not results.fill:
#   |            ^^^^^^^
# 7 |         histOutline.OutlinedHistogram(data, title=title)
# 8 |     else:
#   |
#
# F821 Undefined name `histOutline`
#  --> less_ugly.py:7:9
#   |
# 5 |     # not a great snippet of code here
# 6 |     if not results.fill:
# 7 |         histOutline.OutlinedHistogram(data, title=title)
#   |         ^^^^^^^^^^^
# 8 |     else:
# 9 |         histOutline.RegularHistogram(data, title=title)
#   |
#
# F821 Undefined name `data`
#  --> less_ugly.py:7:39
#   |
# 5 |     # not a great snippet of code here
# 6 |     if not results.fill:
# 7 |         histOutline.OutlinedHistogram(data, title=title)
#   |                                       ^^^^
# 8 |     else:
# 9 |         histOutline.RegularHistogram(data, title=title)
#   |
#
# F821 Undefined name `histOutline`
#  --> less_ugly.py:9:9
#   |
# 7 |         histOutline.OutlinedHistogram(data, title=title)
# 8 |     else:
# 9 |         histOutline.RegularHistogram(data, title=title)
#   |         ^^^^^^^^^^^
#   |
#
# F821 Undefined name `data`
#  --> less_ugly.py:9:38
#   |
# 7 |         histOutline.OutlinedHistogram(data, title=title)
# 8 |     else:
# 9 |         histOutline.RegularHistogram(data, title=title)
#   |                                      ^^^^
#   |
#
# Found 5 errors.

# %%
# %load ugly.py

# %% [markdown]
# ## Other helpful linters
#
#   - Ensuring that the code you commit is PEP8 clean: https://stackoverflow.com/a/70335915
#   - **nbQA**...PEP8 and working with Jupyter notebooks: https://github.com/nbQA-dev/nbQA#-examples

# %% [markdown]
# ## Testing - pytest ##
#
# Unit tests, regression tests, integration tests....
#
# * `pytest` is the standard test runner that discovers and runs pre-defined tests, and reports back the results
# * within your code, add test functions that act as self-checks
# * naming convention: test*
# * lay out everything you want your code to do beforehand, as a self check
#     * test-driven development

# %% [markdown]
# write test functions that use the `assert` command - it raises an `AssertionError` if it does not evaluate to true
#
# ```python
# #[ within my code ]
# def square_me(x):
#     return x**2
#
# def test_1():
#     # test the simple square_me function
#     assert square_me(2.) == 4.
#
# def test_2():
#     # testing without an absolute equality
#     assert abs(square_me(2.34) - 5.4756) < .001
# ```

# %%
# %%writefile mycode.py
import math
from unittest import TestCase


def square_me(x):
    return x**2


def test_1():
    # test the simple square_me function
    assert square_me(2.) == 4.


def test_2():
    # testing without an absolute equality
    assert abs(square_me(2.34) - 5.4756) < 0.001

    
## can also make a class which is a subclass of TestCase...
class TestOneNumber(TestCase):
    def test_floats(self):
        for num in [1617161771.7650001, math.pi, math.pi**100,
                    math.pi**-100, 3.1]:
            self.assertEqual(square_me(num), pow(num,2))
# Out:
# Overwriting mycode.py

# %%
# !uv run pytest mycode.py --verbose
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.6, pytest-9.0.2, pluggy-1.5.0 -- /Users/jbloom/miniforge3/bin/python3.10
# cachedir: .pytest_cache
# rootdir: /Users/jbloom/Classes/ay256/course_materials_sp2026
# configfile: pyproject.toml
# plugins: factoryboy-2.5.1, anyio-4.9.0, asyncio-1.3.0, Faker-15.3.4
# asyncio: mode=strict, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 3 items
#
# mycode.py::test_1 PASSED                                                 [ 33%]
# mycode.py::test_2 PASSED                                                 [ 66%]
# mycode.py::TestOneNumber::test_floats PASSED                             [100%]
#
# ============================== 3 passed in 0.13s ===============================

# %% [markdown]
# # Breakout
# <img src="https://s-media-cache-ak0.pinimg.com/originals/1b/d0/1c/1bd01c1c610b18d61482f831a11649ed.jpg">

# %% [markdown]
# Fix this code and write some new test cases to handle other possible inputs:

# %%
# %%writefile calvin.py

"""
Broken Behavior ... fix the tests/functions and add another test
"""

class Transmogrifier:

    def transmogrify(self, person):
        """ Transmogrify someone
        """
        
        transmog = {'calvin':'eel',
                     'hobbes':'bug'}
        new_person = transmog[person]
        return new_person


def test_transmogrify():
    TM = Transmogrifier()
    for p in ['Calvin', 'Hobbes']:
        assert TM.transmogrify(p) != None

        
def main():
    TM = Transmogrifier()
    for p in ['Calvin', 'Hobbes']:
        print(p, '->  ZAP!  ->', TM.transmogrify(p))
# Out:
# Overwriting calvin.py

# %%
# %run calvin.py

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/l6/qxz619j9671dr9wn886bbk540000gn/T/ipykernel_14834/451043146.py in <module>
# ----> 1 main()
#
# ~/Classes/ay256/course_materials_sp2026/lectures/Lecture09_reports_packaging/calvin.py in main()
#      25     TM = Transmogrifier()
#      26     for p in ['Calvin', 'Hobbes']:
# ---> 27         print(p, '->  ZAP!  ->', TM.transmogrify(p))
#
# ~/Classes/ay256/course_materials_sp2026/lectures/Lecture09_reports_packaging/calvin.py in transmogrify(self, person)
#      12         transmog = {'calvin':'eel',
#      13                      'hobbes':'bug'}
# ---> 14         new_person = transmog[person]
#      15         return new_person
#      16
#
# KeyError: 'Calvin'

# %%
# !uv run pytest calvin.py --verbose
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.6, pytest-9.0.2, pluggy-1.5.0 -- /Users/jbloom/miniforge3/bin/python3.10
# cachedir: .pytest_cache
# rootdir: /Users/jbloom/Classes/ay256/course_materials_sp2026
# configfile: pyproject.toml
# plugins: factoryboy-2.5.1, anyio-4.9.0, asyncio-1.3.0, Faker-15.3.4
# asyncio: mode=strict, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function
# collected 1 item
#
# calvin.py::test_transmogrify FAILED                                      [100%]
#
# =================================== FAILURES ===================================
# ______________________________ test_transmogrify _______________________________
#
#     def test_transmogrify():
#         TM = Transmogrifier()
#         for p in ['Calvin', 'Hobbes']:
# >           assert TM.transmogrify(p) != None
#
# calvin.py:21:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <calvin.Transmogrifier object at 0x1016f3a00>, person = 'Calvin'
#
#     def transmogrify(self, person):
#         """ Transmogrify someone
#         """
#
#         transmog = {'calvin':'eel',
#                      'hobbes':'bug'}
# >       new_person = transmog[person]
# E       KeyError: 'Calvin'
#
# calvin.py:14: KeyError
# =========================== short test summary info ============================
# FAILED calvin.py::test_transmogrify - KeyError: 'Calvin'
# ============================== 1 failed in 0.10s ===============================

# %% [markdown]
# <img src="http://i.imgur.com/pxFdZSe.gif">
