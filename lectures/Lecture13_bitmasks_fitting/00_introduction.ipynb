# %% [markdown]
# # Lecture 13: Lab 2 ``The Cannon", More Technical Stuff
#
# ### Mar. 5, 2026

# %% [markdown]
# # Lab 2
#
#   - PDF of the Lab is on [GitHub](https://github.com/ucb-datalab/course_materials_sp2026/blob/main/labs/lab_2/AY128_Lab2_apogee_spectra_spring2026.pdf).

# %% [markdown]
# # Agenda
#
# - Introduction (this notebook, *00_Introduction*)
# - Bitmasks
# - Stocks (*01_Fitting_Stocks_Model*)
# - More Cannon (*02_The_Cannon*)
