# %% [markdown]
# # Meeting/Lecture 1 - Jan 22, 2026
#
# ## Agenda
#
# * Office Hours
#     - Josh:  5-6pm Tues in Campbell 355
#     - Saahit: 1pm-2pm Mon, 12:30-2pm Tues, 1-2pm Fri
# * Due Dates
#     - See [PDF](https://github.com/ucb-datalab/course_materials_sp2026/blob/main/labs/AY128_Lab0_adql_gaia_spring2026.pdf)
#     - CP1: due Tues Jan 27.
# * Introduction (this notebook, *00_Introduction*)
# * H-R Diagrams (*Lecture00_Viz_and_Caching/02_HR*)
# * Parallax (*01_demo_parallax_proper_motion*)
# * Gaia (*02_Gaia*) (required at home reading)
# * Caching (*Lecture00_Viz_and_Caching/04_caching*)
# * Example checkpoint presentation
#
# ## Getting these notebooks
# ```bash
# git clone git clone https://github.com/ucb-datalab/course_materials_sp2026.git
# cd course_materials_sp2026.git
# jupyter notebook
# ```
