# %% [markdown]
# # Lecture 13: Lab 2 ``The Cannon", Technical Stuff
#
# ### Mar. 3, 2026

# %% [markdown]
# # Lab 2
#
#   - PDF of the Lab is on [GitHub](https://github.com/ucb-datalab/course_materials_sp2026/tree/main/labs/lab_2).

# %% [markdown]
# # Agenda
#
# - Introduction (this notebook, *00_Introduction*)
# - Review Lab 2 Radiative Transfer
# - Review Stellar Spectra
# - FITS files and bitmasks (*01_bitmasks_example_spectra*)
# - More Cannon (*02_The_Cannon*)
