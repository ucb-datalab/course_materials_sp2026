# %% [markdown]
# # Lecture 25: Lab 3 Checkpoint Presentations + Convnets
#
# ### April 14, 2026

# %% [markdown]
# # Lab 3
#
#   - PDF of the Lab is on [GitHub](https://github.com/ucb-datalab/course_materials_sp2026/blob/main/labs/lab_3/AY128_Lab3_image_classification_spring2026.pdf).
#
#   - **Assigned**: Apr. 14, 2026
#   - **Checkpoints**: Tue Apr. 21, 2026; Thu Apr. 30, 2026
#   - Final Write Up (in $\LaTeX$/PDF) Due: 1:59 PM Fri May. 8, 2026

# %% [markdown]
# # Agenda
#
# - Introduction (this notebook, *00_introduction*)
# - Presentations
# - Convolutional Neural Nets with PyTorch Lightning (*01_CNNs_pytorch*)
