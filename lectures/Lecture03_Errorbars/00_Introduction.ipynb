# %% [markdown]
# # AY 128: Meeting/Lecture 3
#
# ## Agenda
#
# * Introduction (this notebook, *00_Introduction*)
# * Intro to $\chi^2$ (*01_chisq_intro*) part 1
# * Checkpoint \#2 Group Discussions
# * Central Limit Theorem (*02_central_limit*)
# * Errorbars: More on $\chi^2$ (*01_chisq_part2*)

# %% [markdown]
# # Checkpoint groupings
#
# Let's get into groups...randomly, but deterministically...

# %%
students = []

# %%
print(f"Today we have {len(students)} students.")
print(f"There are no name conflicts: {len(students) == len(set(students))}")
# Out:
# Today we have 0 students.
# There are no name conflicts: True

# %% [markdown]
# If you dont know about f-strings, today is your lucky day. They were introduced in Python 3.6 and they rock!
#
# Some links for you: - https://docs.python.org/3/whatsnew/3.6.html#whatsnew36-pep498 - https://docs.python.org/3/reference/lexical_analysis.html#f-strings

# %%
preferred_size_of_group = 5
smallest_group_size = 3

# %%
print(f"With a preferred group size of {preferred_size_of_group} the smallest group would be {len(students) % preferred_size_of_group}")
print(f"That is {'fine.' if len(students) % preferred_size_of_group >= smallest_group_size else 'Unacceptable!'}")
# Out:
# With a preferred group size of 5 the smallest group would be 0
# That is Unacceptable!

# %%
import numpy as np
import pandas as pd 
import scipy as sp

n_groups = int(np.ceil(len(students) / preferred_size_of_group))
print(f"Number of groups will be {n_groups}.")
# Out:
# Number of groups will be 0.

# %% [markdown]
# When using randomness, it's almost always a good idea to be able to reproduce the results. Pseudo-random number generators are "seeded" with a number and then yield seemingly random numbers after that. But those numbers are deterministic given the seed and the calling sequence of the generator.
#
# See https://www.numpy.org/devdocs/reference/generated/numpy.random.RandomState.html

# %%
np.random.randint(10, 100)
# Out:
# 66

# %%
class_seed =  0 # let's set this together
rnd = np.random.RandomState(class_seed)

# %%
import copy

shuffled_students = copy.copy(students)
rnd.shuffle(shuffled_students)
shuffled_students
# Out:
# []

# %%
Now make the groups...

# %%
for group_num, members in enumerate(np.array_split(shuffled_students,  n_groups)):
    print(f"Group {group_num}: {', '.join(list(members))}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 for group_num, members in enumerate(np.array_split(shuffled_students,  n_groups)):
#       2     print(f"Group {group_num}: {', '.join(list(members))}")
#
# File ~/Classes/ay256/course_materials_sp2026/.venv/lib/python3.12/site-packages/numpy/lib/_shape_base_impl.py:789, in array_split(ary, indices_or_sections, axis)
#     787 Nsections = int(indices_or_sections)
#     788 if Nsections <= 0:
# --> 789     raise ValueError('number sections must be larger than 0.') from None
#     790 Neach_section, extras = divmod(Ntotal, Nsections)
#     791 section_sizes = ([0] +
#     792                  extras * [Neach_section + 1] +
#     793                  (Nsections - extras) * [Neach_section])
#
# ValueError: number sections must be larger than 0.
