# %% [markdown]
# # Lecture 7: MCMC Convergence & PyMC
#
# ### Feb 12, 2026

# %% [markdown]
# ## Announcements
#
# - Checkpoint 1 due at 11:59 PM **today**
# - Checkpoint 2 due 2/24

# %% [markdown]
# ## Agenda
#
# - Introduction (this notebook, *00_Introduction*)
# - Checkpoint 1 Discussion
# - Convergence (*01_convergence*)
# - pymc Walkthrough (*02_pymc_fitting_tutorial*)

# %% [markdown]
# ## Checkpoint Discussion
#
# Let's get into groups!

# %%
import numpy as np 
import copy

students = ["Aashni", "Alejandra", "Allison", "Ananya", "Arnav", "Ben", 
            "Beto", "Brad", "Clara", "Daivik", "Elizabeth", "Eric", "Ernest", 
            "Evan", "Flora", "Grant", "Henry", "Iris", "Isha", "Jean", 
            "Joshua", "Jun Rui", "Jyotsna", "Karin", "Leire", "Leo", "Lerin", 
            "Queen", "Rheanna", "Ryan", "Sabrina", "Shaurya", "Sierra", 
            "Sophia", "Suhani", "Tiffany", "Veda", "Yuhan"]
shuffled_students = copy.copy(students)
rng = np.random.default_rng(seed=67)
rng.shuffle(shuffled_students)
n_groups = 6

for group_num, members in enumerate(np.array_split(shuffled_students, n_groups)):
    print(f"Group {group_num}: {', '.join(list(members))}")
